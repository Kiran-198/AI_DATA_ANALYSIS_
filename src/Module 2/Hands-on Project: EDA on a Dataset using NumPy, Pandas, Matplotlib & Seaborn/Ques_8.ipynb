# %%
# Title: Advanced Data Visualization
# Description: Create a pair plot for the dataset to display pairwise relationships.
# Advanced Data Visualization

# Import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Convert to a DataFrame
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add species column
iris_df['species'] = pd.Series(iris.target).map(dict(enumerate(iris.target_names)))

# Create a pair plot
sns.set(style="ticks")
sns.pairplot(iris_df, hue="species", diag_kind="kde", palette="husl")

# Display the plot
plt.suptitle("Pairwise Feature Relationships - Iris Dataset", y=1.02)
plt.show()
